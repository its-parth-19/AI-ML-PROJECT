# %% [markdown]
# #                                                                ABOUT THE DATASET:
#
#
# What is Autism:
# Autism, or autism spectrum disorder (ASD), refers to a broad range of conditions characterized by challenges with social skills, repetitive behaviors, speech and nonverbal communication.
#
#
# CAUSES AND CHALLENGES:
# It is mostly influenced by a combination of genetic and environmental factors. Because autism is a spectrum disorder, each person with autism has a distinct set of strengths and challenges.esearch has made clear that high quality early intervention can improve learning, communication and social skills, as well as underlying brain development.
#
#
# ROLE OF MACHINE LEARNING:
# This dataset is composed of survey results for more than 700 people who filled an app form. There are labels portraying whether the person received a diagnosis of autism, allowing machine learning models to predict the likelihood of having autism, therefore allowing healthcare professionals prioritize their resources.

# %%
# LOOK ON FEATURE DESCRIPTION:
    
    
    
Feature------------------------------------------	Description
index-------------------------------------------	The participant’s ID number
AX_Score-----------------------------------------	Score based on the Autism Spectrum Quotient (AQ).
age-----------------------------------------------	Age in years
gender-------------------------------------------	Male or Female
ethnicity---------------------------------------	Ethnicities in text form
jaundice----------------------------------------	Whether or not the participant was born with jaundice?
autism-------------------------------------------	Whether or not anyone in tbe immediate family has been diagnosed with autism?
country_of_res----------------------------------	Countries in text format
used_app_before------------------------------------	Whether the participant has used a screening app
result---------------------------------------------	Score from the AQ-10 screening tool
age_desc----------------------------------------	Age as categorical
relation----------------------------------------	Relation of person who completed the test
Class/ASD---------------------------------------	Participant classification
# Out:
#   Cell In[1], line 6
#     index-------------------------------------------	The participant’s ID number
#                                                     	               ^
# SyntaxError: invalid character '’' (U+2019)

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sb
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder, StandardScaler
# from sklearn import metrics
# from sklearn.svm import SVC
# # from xgboost import XGBClassifier
# from sklearn.linear_model import LogisticRegression
# from imblearn.over_sampling import RandomOverSampler

# %% [markdown]
# # DATA ANALYSIS:

# %%
df=pd.read_csv("autism_screening.csv")
df
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  \
# ...

# %%
df = df.dropna()

# %%
df.shape                     #it tells us the number of rows*number of columns in our dataset.
# Out:
# (702, 21)

# %%
df.head()                      #it gives us the full description of table for only first five rows.
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice austim  \
# 0         1         0          0  ...       f  White-European      no     no
# 1         1         0          1  ...       m          Latino      no    yes
# 2         1         1          1  ...       m          Latino     yes    yes
# 3         1         0          1  ...       f  White-European      no    yes
# 4         1         0          0  ...       f               ?      no     no
#
# ...

# %%
df.tail()                         #it gives us the details about last 5 rows of our dataset.
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  \
# 699         1         1          1  ...       f  White-European      no
# 700         1         0          1  ...       m        Hispanic      no
# 701         1         0          1  ...       f               ?      no
# 702         0         1          1  ...       m     South Asian      no
# 703         1         1          1  ...       f  White-European      no
#
#     austim contry_of_res used_app_before result     age_desc relation  \
# ...

# %% [markdown]
# **It gives us the short view of our complete dataframe specifying their column name,null values if any,and their data types.**

# %%
df.info()  
#it gives us the short view of our complete dataframe specifying their column name,null values if any,and their data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 702 entries, 0 to 703
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   A1_Score         702 non-null    int64
#  1   A2_Score         702 non-null    int64
#  2   A3_Score         702 non-null    int64
#  3   A4_Score         702 non-null    int64
#  4   A5_Score         702 non-null    int64
#  5   A6_Score         702 non-null    int64
#  6   A7_Score         702 non-null    int64
#  7   A8_Score         702 non-null    int64
#  8   A9_Score         702 non-null    int64
#  9   A10_Score        702 non-null    int64
#  10  age              702 non-null    float64
#  11  gender           702 non-null    object
#  12  ethnicity        702 non-null    object
#  13  jundice          702 non-null    object
#  14  austim           702 non-null    object
#  15  contry_of_res    702 non-null    object
#  16  used_app_before  702 non-null    object
# ...

# %%
df.describe()
# Out:
#          A1_Score    A2_Score    A3_Score    A4_Score    A5_Score    A6_Score  \
# count  702.000000  702.000000  702.000000  702.000000  702.000000  702.000000
# mean     0.723647    0.452991    0.458689    0.497151    0.498575    0.284900
# std      0.447512    0.498140    0.498646    0.500348    0.500354    0.451689
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          A7_Score    A8_Score    A9_Score   A10_Score         age      result
# count  702.000000  702.000000  702.000000  702.000000  702.000000  702.000000
# mean     0.417379    0.650997    0.324786    0.574074   29.698006    4.883191
# ...

# %%
df.describe(include=['object'])
# Out:
#        gender       ethnicity jundice austim  contry_of_res used_app_before  \
# count     702             702     702    702            702             702
# unique      2              12       2      2             67               2
# top         m  White-European      no     no  United States              no
# freq      366             233     633    611            113             690
#
#            age_desc relation Class/ASD
# count           702      702       702
# unique            1        6         2
# top     18 and more     Self        NO
# freq            702      522       513

# %% [markdown]
# CONCLUSIONS:
#     1.The ethnicity column the highest is White-European
#     2.The contry_of_res column the highest is United States
#     3.The highest number recorded was for men

# %% [markdown]
# # DATA CLEANING ON DATASET

# %%
df['ethnicity'].value_counts() #value_counts-->counts the number of same thing repeatedly comming.
# Out:
# ethnicity
# White-European     233
# Asian              123
# ?                   93
# Middle Eastern      92
# Black               43
# South Asian         36
# Others              30
# Latino              20
# Hispanic            13
# Pasifika            12
# Turkish              6
# others               1
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# m    366
# f    336
# Name: count, dtype: int64

# %%
df['austim'].value_counts()
# Out:
# austim
# no     611
# yes     91
# Name: count, dtype: int64

# %%
df['relation'].value_counts()
# Out:
# relation
# Self                        522
# ?                            93
# Parent                       50
# Relative                     28
# Others                        5
# Health care professional      4
# Name: count, dtype: int64

# %%
df['Class/ASD'].value_counts()
# Out:
# Class/ASD
# NO     513
# YES    189
# Name: count, dtype: int64

# %%
df.isnull().sum()    #we see that age has 2 null values in it..
# Out:
# A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                0
# gender             0
# ethnicity          0
# jundice            0
# austim             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# dtype: int64

# %%
df = df.replace({'yes':1, 'no':0, '?':'Others', 'others':'Others', 'YES':1, 'NO':0})
print(df['ethnicity'].value_counts() )  #verified that replace statement works correctly.
print()
print(df['austim'].value_counts())
print()
# Out:
# ethnicity
# White-European     233
# Others             124
# Asian              123
# Middle Eastern      92
# Black               43
# South Asian         36
# Latino              20
# Hispanic            13
# Pasifika            12
# Turkish              6
# Name: count, dtype: int64
#
# austim
# 0    611
# 1     91
# Name: count, dtype: int64

# %%
for i in df.columns:
    if df[i].isnull().sum() > 0:
        if df[i].dtype == 'float64':
            val = df[i].mean()
            df[i] = df[i].fillna(val)
        else:
            df = df.dropna(subset=df.select_dtypes(include=['object']).columns)

# %%
df.isnull().sum()
# Out:
# A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                0
# gender             0
# ethnicity          0
# jundice            0
# austim             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# dtype: int64

# %%
print(df.head())
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  austim  \
# 0         1         0          0  ...       f  White-European       0       0
# 1         1         0          1  ...       m          Latino       0       1
# 2         1         1          1  ...       m          Latino       1       1
# 3         1         0          1  ...       f  White-European       0       1
# 4         1         0          0  ...       f          Others       0       0
#
# ...

# %%
cat_cols=df.select_dtypes(include=['object']).columns.tolist()
num_cols = df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print()
print(cat_cols)
print()
print("Numerical Variables:")
print()
print(num_cols)
# Out:
# Categorical Variables:
#
# ['gender', 'ethnicity', 'contry_of_res', 'age_desc', 'relation']
#
# Numerical Variables:
#
# ['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'jundice', 'austim', 'used_app_before', 'result', 'Class/ASD']

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA)

# %%
import plotly.express as px

# %%
plt.pie(df['Class/ASD'].value_counts().values, autopct='%1.2f%%',labels=['No Austim', 'Austim'],colors=['grey','green'])
plt.show()

# %%
plt.pie(df['jundice'].value_counts().values, autopct='%1.2f%%',labels=['No jundice', 'jundice'],colors=['yellow','grey'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(df, x='contry_of_res', hue='Class/ASD')
plt.title('Count Plot of contry_of_res Columns ')
plt.xticks(rotation=90)
plt.show()

# %%
def convertAge(age):
    if age < 18:
        return 'Teenager'
    elif age < 40:
        return 'Young'
    else:
        return 'Senior'
df['ageGroup'] = df['age'].apply(convertAge)

# %%
sns.countplot(x=df['ageGroup'], hue=df['Class/ASD'])
plt.title('Testing different ages')
plt.show()

# %%
values = list(df['result'].value_counts().sort_index().values)
sorted_index = df['result'].value_counts().sort_index().index

# %%
sns.countplot(x=df['result'], hue=df['Class/ASD'])
plt.title('Indicates the result of summing the tests together')
for i in range(len(sorted_index)):
    plt.text(i, values[i] + 0.5, str(values[i]), ha='center')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='Class/ASD', y='age')
plt.title('Age Distribution based on ASD Diagnosis')
plt.xlabel('ASD Diagnosis (0: No, 1: Yes)')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# Conclusions:
# In this study, it has been observed that the average age for individuals with autism is 30 years, while for those without autism, it is 29 years. This difference in average age may indicate a relationship between age and autism.

# %%
df['result'].value_counts()
# Out:
# result
# 4.0     130
# 3.0     110
# 5.0      83
# 2.0      74
# 6.0      70
# 7.0      57
# 8.0      55
# 9.0      47
# 1.0      33
# 10.0     30
# 0.0      13
# Name: count, dtype: int64

# %%
ints = []
objects = []
floats = []
 
for col in df.columns:
  if df[col].dtype == 'int64':
    ints.append(col)
  elif df[col].dtype == object:
    objects.append(col)
  else:
    floats.append(col)

# %%
ints.remove('austim')
ints.remove('used_app_before')
ints.remove('Class/ASD')

# %%
plt.subplots(figsize=(15,15))
 
for i, col in enumerate(ints):
  plt.subplot(4,3,i+1)
  sns.countplot(x=df[col], hue=df['Class/ASD'])
plt.tight_layout()

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_30916\3960620923.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4,3,i+1)

# %%
plt.subplots(figsize=(15,15))
 
for i, col in enumerate(ints):
  plt.subplot(4,3,i+1)
  sns.countplot(x=df[col], hue=df['austim'])
plt.tight_layout()

plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_30916\1469442539.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(4,3,i+1)

# %%
plt.subplots(figsize=(15, 30))
 
for i, col in enumerate(objects):
    plt.subplot(5, 3, i+1)
    sns.countplot(x=df[col], hue=df['Class/ASD'])
    plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_30916\954011707.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(5, 3, i+1)

# %%
plt.barh(list(df['ethnicity'].value_counts().keys()), list(df['ethnicity'].value_counts()), color= ['#BB8493','#49243E'])
plt.title("Number of people Belonging to certain ethnicity")
plt.show()

# %%
df.groupby(['gender', 'Class/ASD']).size().plot(kind='barh', color=['#BB8493','#49243E'])
plt.title('Number of people Having Autism on the Basis of their Sex')
plt.ylabel("Genders,Autism")
plt.xlabel("No of people")
plt.show()

# %%
df.groupby(['gender', 'jundice']).size().plot(kind='barh', color=['#BB8493','#49243E'])
plt.title('Number of people Having JAUNDICE on the Basis of their Sex')
plt.show()

# %%
df.groupby(['jundice', 'Class/ASD']).size().plot(kind='barh', color=['#BB8493','#49243E'])
plt.title('Number of people Having jaundice on the basis of autism')
plt.show()

# %%
sns.countplot(x=df['used_app_before'], hue=df['gender'])
plt.title('Screening app used by the Different Genders')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.bar(list(df['relation'].value_counts().keys()), list(df['relation'].value_counts()), color= ['#BB8493','#49243E'])
plt.title('Who Completed the Test')
plt.show()

# %%
def pair_plot(data, columns, target_column, palette='viridis'):
    sns.pairplot(data[columns + [target_column]], hue=target_column, palette=palette)
    plt.show()

# pair_plot(autism_data, ['Age_Mons', 'Qchat-10-Score', 'A1'], 'Class/ASD Traits ')
# pair_plot(autism_data, ['A2', 'A3', 'A4'], 'Class/ASD Traits ')
# pair_plot(autism_data, ['A5', 'A6', 'A7'], 'Class/ASD Traits ')
# pair_plot(autism_data, ['A8', 'A9', 'A10'], 'Class/ASD Traits ')
pair_plot(df, ['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score'], 'Class/ASD')
pair_plot(df, ['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score', 'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score'], 'jundice')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(data=df, x='age', y='gender', hue='Class/ASD')
plt.title('Result Distribution based on Gender and Age')
plt.xlim(0, 100) 
plt.xticks(range(0, 101, 10)) 
plt.xlabel('Gender')
plt.ylabel('Age')
plt.savefig('Result Distribution based on Gender and Age box.png')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='ethnicity', y='result')
plt.title('Result Distribution based on Ethnicity')
plt.xlabel('Ethnicity')
plt.ylabel('Result')
plt.xticks(rotation=45)
plt.savefig('ethnicity.png')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='gender', y='age', hue='Class/ASD')
plt.title('Result Distribution based on Gender and Age')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.savefig('Result Distribution based on Gender and Age.png')
plt.show()

# %%
cross_tab = pd.crosstab(index=df['jundice'], columns=df['Class/ASD'])

sns.heatmap(cross_tab, annot=True, fmt='d')
plt.title('Heatmap of Jaundice and Class/ASD')
plt.xlabel('Class/ASD')
plt.ylabel('Jaundice')
plt.show()

# %%
cross_tab = pd.crosstab(index=df['Class/ASD'], columns=df['gender'])

sns.heatmap(cross_tab, annot=True, fmt='d')
plt.title('Heatmap of Autism and Genders')
plt.xlabel('Gender')
plt.ylabel('Class/ASD')
plt.show()

# %%
cross_tab = pd.crosstab(index=df['Class/ASD'], columns=df['result'])

sns.heatmap(cross_tab, annot=True, fmt='d')
plt.title('Heatmap of Autism and Result')
plt.xlabel('Result')
plt.ylabel('Class/ASD')
plt.show()

# %%
cross_tab = pd.crosstab(index=df['austim'], columns=df['Class/ASD'])

sns.heatmap(cross_tab, annot=True, fmt='d')
plt.title('Heatmap of Austim and Class/ASD')
plt.xlabel('Class/ASD')
plt.ylabel('Austim')
plt.show()

# %%
sns.pairplot(df, hue='Class/ASD', palette='viridis')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # OUTLIERS DETECTION

# %% [raw]
# *we see that outlier is detected in age columns let's fix it and improves our model for further working.

# %%
def box_plots(data, column1, column2):
    plt.figure(figsize=(5, 5))
    sns.boxplot(data=data[[column1, column2]], palette='viridis')
    plt.show()

box_plots(df, 'age', 'result')
box_plots(df, 'A1_Score', 'A2_Score')
box_plots(df, 'A3_Score', 'A4_Score')
box_plots(df, 'A5_Score', 'A6_Score')
box_plots(df, 'A7_Score', 'A8_Score')
box_plots(df, 'A9_Score', 'A10_Score')
box_plots(df, 'result', 'A1_Score')
box_plots(df, 'result', 'A2_Score')
box_plots(df,'age','A1_Score')

# %%
df['age'].skew()
df['age'].describe()
# Out:
# count    702.000000
# mean      29.698006
# std       16.507465
# min       17.000000
# 25%       21.000000
# 50%       27.000000
# 75%       35.000000
# max      383.000000
# Name: age, dtype: float64

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: >

# %%
percentile_25=df['age'].quantile(0.25)
percentile_75=df['age'].quantile(0.75)

# %%
iqr=percentile_75-percentile_25

# %%
upper_limit=percentile_75+1.5*iqr
lower_limit=percentile_25-1.5*iqr

# %%
print(upper_limit)
print(lower_limit)
# Out:
# 56.0
# 0.0

# %% [markdown]
# # OUTLIERS DETECTED BELOW

# %%
df[df['age']>upper_limit]
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 7           1         1         1         1         0         0         0
# 52          1         0         0         0         0         0         0
# 71          0         0         1         1         0         0         0
# 203         1         1         1         1         1         1         1
# 309         1         1         1         1         1         1         0
# 431         1         1         1         1         1         1         1
# 448         1         1         1         1         1         1         1
# 495         1         0         1         1         0         0         0
#
#      A8_Score  A9_Score  A10_Score  ...        ethnicity jundice austim  \
# 7           0         1          0  ...   White-European       0      0
# 52          0         0          0  ...         Pasifika       0      0
# 71          1         0          0  ...            Asian       0      0
# ...

# %%
df[df['age']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [A1_Score, A2_Score, A3_Score, A4_Score, A5_Score, A6_Score, A7_Score, A8_Score, A9_Score, A10_Score, age, gender, ethnicity, jundice, austim, contry_of_res, used_app_before, result, age_desc, relation, Class/ASD, ageGroup]
# Index: []
#
# [0 rows x 22 columns]

# %%
new_df=df[df['age']<upper_limit]
new_df
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...       ethnicity jundice austim  \
# ...

# %% [markdown]
# # LET'S FIX THE OUTLIER AND SEE AGAIN BOX PLOT OF AGE

# %%
new_df_cap=df.copy()
new_df_cap['age']=np.where(
new_df_cap['age']>upper_limit,
upper_limit,
np.where(
new_df_cap['age']<lower_limit,
lower_limit,
new_df_cap['age']))

# %%
new_df_cap.shape
# Out:
# (702, 22)

# %% [markdown]
# # OUTLIERS REMOVED SUCCESSFULLLY

# %%
def box_plots(data, column1, column2):
    plt.figure(figsize=(5, 5))
    sns.boxplot(data=data[[column1, column2]], palette='viridis')
    plt.show()

box_plots(new_df_cap, 'age', 'result')
box_plots(new_df_cap, 'A1_Score', 'A2_Score')
box_plots(new_df_cap, 'A3_Score', 'A4_Score')
box_plots(new_df_cap, 'A5_Score', 'A6_Score')
box_plots(new_df_cap, 'A7_Score', 'A8_Score')
box_plots(new_df_cap, 'A9_Score', 'A10_Score')
box_plots(new_df_cap, 'result', 'A1_Score')
box_plots(new_df_cap, 'result', 'A2_Score')
box_plots(new_df_cap,'age','A1_Score')

# %% [markdown]
# # FEATURE EXTRACTION

# %%
df.columns
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'gender',
#        'ethnicity', 'jundice', 'austim', 'contry_of_res', 'used_app_before',
#        'result', 'age_desc', 'relation', 'Class/ASD', 'ageGroup'],
#       dtype='object')

# %%
df = df.drop('age_desc', axis=1)

# %%
df.shape
# Out:
# (702, 21)

# %%
df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  austim  \
# 0         1         0          0  ...       f  White-European       0       0
# 1         1         0          1  ...       m          Latino       0       1
# 2         1         1          1  ...       m          Latino       1       1
# 3         1         0          1  ...       f  White-European       0       1
# 4         1         0          0  ...       f          Others       0       0
#
# ...

# %%
df.tail()
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  \
# 699         1         1          1  ...       f  White-European       0
# 700         1         0          1  ...       m        Hispanic       0
# 701         1         0          1  ...       f          Others       0
# 702         0         1          1  ...       m     South Asian       0
# 703         1         1          1  ...       f  White-European       0
#
#      austim  contry_of_res used_app_before  result  relation Class/ASD  \
# ...

# %%
def convertAge(age):
    if age < 18:
        return 'Teenager'
    elif age < 40:
        return 'Young'
    else:
        return 'Senior'
df['ageGroup'] = df['age'].apply(convertAge)

# %%
sns.countplot(x=df['ageGroup'], hue=df['Class/ASD'])
plt.title('Testing different ages')
plt.show()

# %% [markdown]
# # PREDICTION

# %% [markdown]
# Convert the Pandas dataframes into numpy arrays that can be used by scikit_learn. Let's create an array that extracts only the feature data we want to work with and another array that contains the classes (class/ASD).

# %%
# data_raw = df['Class/ASD']
# features_raw = df[['age', 'gender', 'ethnicity', 'jundice', 'austim', 'contry_of_res', 'result',
#                       'relation','A1_Score','A2_Score','A3_Score','A4_Score','A5_Score','A6_Score','A7_Score','A8_Score',
#                       'A9_Score','A10_Score']]

# %% [markdown]
# Data Preprocessing : using MinMaxScaler()

# %%
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# num = ['age','result']
# features_minmax_transform = pd.DataFrame(data = features_raw)
# features_minmax_transform[num] = scaler.fit_transform(features_raw[num])

# %%
display(features_minmax_transform.head(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 1
# ----> 1 display(features_minmax_transform.head(5))
#
# NameError: name 'features_minmax_transform' is not defined

# %% [markdown]
# One-Hot Encoding on features_minmax_transform

# %%
# features_final = pd.get_dummies(features_minmax_transform)
# features_final.head(5)

# %% [markdown]
# Encode all classes data to numerical values¶

# %%
# data_classes = data_raw.apply(lambda x : 1 if x == 'YES' else 0)
# encoded = list(features_final.columns)
# print("{} total features after one-hot encoding".format(len(encoded)))
# print(encoded)

# %% [markdown]
# shuffling and spliiting data

# %%
# from sklearn.model_selection import train_test_split
# np.random.seed(123)
# X_train, X_test, y_train, y_test = train_test_split(features_final,data_classes,test_size=0.2, random_state=1)
# print("Train set has {} enteries.".format(X_train.shape[0]))
# print("Test set has {} enteries.".format(X_test.shape[0]))

# %% [markdown]
# # 1. DECISION TREE

# %%
# from sklearn import tree
# from sklearn.tree import DecisionTreeClassifier
# dec_model = DecisionTreeClassifier()
# dec_model.fit(X_train.values, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 4
#       2 from sklearn.tree import DecisionTreeClassifier
#       3 dec_model = DecisionTreeClassifier()
# ----> 4 dec_model.fit(X_train.values, y_train)
#
# NameError: name 'X_train' is not defined

# %%
# y_pred = dec_model.predict(X_test.values)
# print('True : ', y_test.values[0:25])
# print('False :', y_pred[0:25])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 y_pred = dec_model.predict(X_test.values)
#       2 print('True : ', y_test.values[0:25])
#       3 print('False :', y_pred[0:25])
#
# NameError: name 'X_test' is not defined

# %%
# from sklearn import metrics
# cm = metrics.confusion_matrix(y_test, y_pred)
# print(cm)
# TP = cm[1,1]
# FP = cm[0,1]
# TN = cm[0,0]
# FN = cm[1,0]

# %%
# print('Accuracy:')
# print((TN+TP)/float(TP+TN+FP+FN))
# print('Error:')
# print((FP+FN)/float(TP+TN+FP+FN))
# print('Precision:')
# print(metrics.precision_score(y_test,y_pred))
# print('Score:')
# print(dec_model.score(X_test.values, y_test))

# %% [markdown]
# # 2. RANDOM FOREST

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import cross_val_score
# from sklearn.impute import SimpleImputer
# imputer = SimpleImputer(strategy='mean')
# features_final_imputed = imputer.fit_transform(features_final)
# rndm_model = RandomForestClassifier(n_estimators=5, random_state=1)
# cv_score = cross_val_score(rndm_model, features_final_imputed, data_classes, cv=10)

# cv_score.mean()

# %% [markdown]
# # 3.SVM(SUPPORT VECTOR MACHINES)

# %%
# from sklearn import svm
# svm_model = svm.SVC(kernel='linear', C=1, gamma=2)
# cv_score = cross_val_score(svm_model,features_final_imputed , data_classes, cv =10)
# cv_score.mean()

# %% [markdown]
# # 4. LOGISTIC REGRESSION

# %%
# from sklearn.linear_model import LogisticRegression
# lr_model = LogisticRegression()
# cv_score = cross_val_score(lr_model, features_final_imputed, data_classes, cv =10)
# cv_score.mean()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn import svm
import pandas as pd
import numpy as np

# %%
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'gender',
#        'ethnicity', 'jundice', 'austim', 'contry_of_res', 'used_app_before',
#        'result', 'relation', 'Class/ASD', 'ageGroup'],
#       dtype='object')

# %%
# Target Variable   
data_df = df['Class/ASD']
# Select features for training 
features = df[['age', 'gender', 'ethnicity', 'jundice', 'austim', 'contry_of_res', 'result', 'relation',
               'A1_Score','A2_Score','A3_Score','A4_Score','A5_Score','A6_Score','A7_Score','A8_Score', 'A9_Score','A10_Score']]

# Make all the values of age and result a value between 0 and 1   
scaler = MinMaxScaler()
num = ['age', 'result']
features_transform = pd.DataFrame(data = features)
features_transform[num] = scaler.fit_transform(features[num])

display(features_transform.head())
# Out:
#         age gender       ethnicity jundice austim  contry_of_res  result  \
# 0  0.024590      f  White-European      no     no  United States     0.6
# 1  0.019126      m          Latino      no    yes         Brazil     0.5
# 2  0.027322      m          Latino     yes    yes          Spain     0.8
# 3  0.049180      f  White-European      no    yes  United States     0.6
# 4  0.062842      f               ?      no     no          Egypt     0.2
#
#   relation  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  \
# 0     Self         1         1         1         1         0         0
# 1     Self         1         1         0         1         0         0
# 2   Parent         1         1         0         1         1         0
# 3     Self         1         1         0         1         0         0
# 4        ?         1         0         0         0         0         0
#
#    A7_Score  A8_Score  A9_Score  A10_Score
# 0         1         1         0          0
# ...

# %%
# Convert categorical data into dummy variables 
features = pd.get_dummies(features_transform)
features.head()
# Out:
#         age  result  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  \
# 0  0.024590     0.6         1         1         1         1         0
# 1  0.019126     0.5         1         1         0         1         0
# 2  0.027322     0.8         1         1         0         1         1
# 3  0.049180     0.6         1         1         0         1         0
# 4  0.062842     0.2         1         0         0         0         0
#
#    A6_Score  A7_Score  A8_Score  ...  contry_of_res_United Kingdom  \
# 0         0         1         1  ...                         False
# 1         0         0         1  ...                         False
# 2         0         1         1  ...                         False
# 3         0         1         1  ...                         False
# 4         0         0         1  ...                         False
#
#    contry_of_res_United States  contry_of_res_Uruguay  contry_of_res_Viet Nam  \
# ...

# %%
# Encode all classes data to numerical values
data_classes = data_df.apply(lambda x : 1 if x == 'YES' else 0)
data_classes.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Class/ASD, dtype: int64

# %%
# Split the data into train and test sets 
x_train, x_test, y_train, y_test = train_test_split(features, data_classes, test_size = 0.2, random_state = 1)

# Fixes Tensorflow - ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type float)
x_train = np.asarray(x_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
x_test = np.asarray(x_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

print(f'Shape of x_train is : {x_train.shape}')
print(f'Shape of y_train is : {y_train.shape}\n')
print(f'Shape of x_test is : {x_test.shape}')
print(f'Shape of y_test is : {y_test.shape}')
# Out:
# Shape of x_train is : (563, 103)
# Shape of y_train is : (563,)
#
# Shape of x_test is : (141, 103)
# Shape of y_test is : (141,)

# %% [markdown]
# Method to display the performance evaluation metrics of a classification model. Will display the metrics in the order of -
# Confusion Matrix
# Classification Report (Precision, Recall, F1 Score, Support)
# Classification Accuracy
# Cross-Validation Score (CV Score)
# ROC AUC Score

# %% [markdown]
# # SUPPORT VECTOR MACHINES

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.impute import SimpleImputer
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics

def evaluate_model(model, x_test, y_test):
    y_pred = model.predict(x_test)
    cm = confusion_matrix(y_test, y_pred)
    ax = sns.heatmap(cm, annot=True, cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    ax.set_xticklabels(['No Autism', 'Autism'])
    ax.set_yticklabels(['No Autism', 'Autism'], rotation=90, va='center')
    plt.show()

    print(classification_report(y_test, y_pred, target_names=['No Autism', 'Autism']))
    print('Classification Accuracy:', '{0:.4}'.format(metrics.accuracy_score(y_test, y_pred)))
    cv_score = cross_val_score(model, x_test, y_test, cv=10)
    print('CV Score:', '{0:.4}'.format(cv_score.mean()))
    print('ROC AUC Score:', '{0:.2%}'.format(roc_auc_score(y_test, y_pred)))

# Assuming x_train and x_test are your feature matrices with NaN values
# Instantiate SimpleImputer to replace NaN with mean
imputer = SimpleImputer(strategy='mean')

# Fit and transform the imputer on training data
x_train_imputed = imputer.fit_transform(x_train)
x_test_imputed = imputer.transform(x_test)

svm_model = svm.SVC(kernel='linear', C=1, gamma=2)
svm_model.fit(x_train_imputed, y_train)

evaluate_model(svm_model, x_test_imputed, y_test)
# Out:
#               precision    recall  f1-score   support
#
#    No Autism       1.00      1.00      1.00       105
#       Autism       1.00      1.00      1.00        36
#
#     accuracy                           1.00       141
#    macro avg       1.00      1.00      1.00       141
# weighted avg       1.00      1.00      1.00       141
#
# Classification Accuracy: 1.0
# CV Score: 0.9643
# ROC AUC Score: 100.00%

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.impute import SimpleImputer
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics

def evaluate_model(model, x_test, y_test):
    y_pred = model.predict(x_test)
    cm = confusion_matrix(y_test, y_pred)
    ax = sns.heatmap(cm, annot=True, cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    ax.set_xticklabels(['No Autism', 'Autism'])
    ax.set_yticklabels(['No Autism', 'Autism'], rotation=90, va='center')
    plt.show()

    print(classification_report(y_test, y_pred, target_names=['No Autism', 'Autism']))
    print('Classification Accuracy:', '{0:.4}'.format(metrics.accuracy_score(y_test, y_pred)))
    cv_score = cross_val_score(model, x_test, y_test, cv=10)
    print('CV Score:', '{0:.4}'.format(cv_score.mean()))
    print('ROC AUC Score:', '{0:.2%}'.format(roc_auc_score(y_test, y_pred)))

# Assuming x_train and x_test are your feature matrices with NaN values
# Instantiate SimpleImputer to replace NaN with mean
imputer = SimpleImputer(strategy='mean')

# Fit and transform the imputer on training data
x_train_imputed = imputer.fit_transform(x_train)
x_test_imputed = imputer.transform(x_test)

lr_model = LogisticRegression()
lr_model.fit(x_train_imputed, y_train)

evaluate_model(lr_model, x_test_imputed, y_test)
# Out:
#               precision    recall  f1-score   support
#
#    No Autism       1.00      0.99      1.00       105
#       Autism       0.97      1.00      0.99        36
#
#     accuracy                           0.99       141
#    macro avg       0.99      1.00      0.99       141
# weighted avg       0.99      0.99      0.99       141
#
# Classification Accuracy: 0.9929
# CV Score: 0.9719
# ROC AUC Score: 99.52%

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
from sklearn.model_selection import cross_val_score
from sklearn.impute import SimpleImputer
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics

def evaluate_model(model, x_test, y_test):
    y_pred = model.predict(x_test)
    cm = confusion_matrix(y_test, y_pred)
    ax = sns.heatmap(cm, annot=True, cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    ax.set_xticklabels(['No Autism', 'Autism'])
    ax.set_yticklabels(['No Autism', 'Autism'], rotation=90, va='center')
    plt.show()

    print(classification_report(y_test, y_pred, target_names=['No Autism', 'Autism']))
    print('Classification Accuracy:', '{0:.4}'.format(metrics.accuracy_score(y_test, y_pred)))
    cv_score = cross_val_score(model, x_test, y_test, cv=10)
    print('CV Score:', '{0:.4}'.format(cv_score.mean()))
    print('ROC AUC Score:', '{0:.2%}'.format(roc_auc_score(y_test, y_pred)))

# Assuming x_train and x_test are your feature matrices with NaN values
# Instantiate SimpleImputer to replace NaN with mean
imputer = SimpleImputer(strategy='mean')

# Fit and transform the imputer on training data
x_train_imputed = imputer.fit_transform(x_train)
x_test_imputed = imputer.transform(x_test)

rfc_model = RandomForestClassifier(n_estimators=100, random_state=1)
rfc_model.fit(x_train_imputed, y_train)

evaluate_model(rfc_model, x_test_imputed, y_test)
# Out:
#               precision    recall  f1-score   support
#
#    No Autism       1.00      1.00      1.00       105
#       Autism       1.00      1.00      1.00        36
#
#     accuracy                           1.00       141
#    macro avg       1.00      1.00      1.00       141
# weighted avg       1.00      1.00      1.00       141
#
# Classification Accuracy: 1.0
# CV Score: 1.0
# ROC AUC Score: 100.00%
